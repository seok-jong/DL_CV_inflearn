# %%
import tensorflow as tf
#tensorflow_hub import 수행. 
import tensorflow_hub as hub
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
# Out:
# 2.8.0

# %%
# !nvidia-smi
# Out:
# Fri May 20 15:45:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.129.06   Driver Version: 470.129.06   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:13:00.0  On |                  N/A |
# |  0%   54C    P5    17W / 220W |    307MiB /  7965MiB |      7%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       988      G   /usr/lib/xorg/Xorg                 97MiB |
# |    0   N/A  N/A      1285      G   /usr/bin/gnome-shell               66MiB |
# |    0   N/A  N/A      1666      G   ...RendererForSitePerProcess       63MiB |
# |    0   N/A  N/A      1828      G   ...803133422215954456,131072       76MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### 입력 이미지로 사용될 이미지 다운로드

# %%
# !mkdir /content/data
# !wget -O ./data/beatles01.jpg https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/beatles01.jpg

# %% [markdown]
# ### TF Hub에서 SSD Inference 모델 다운로드 후 Inference 수행.
# * 원하는 모델명은 TF Hub에서 검색해서 hub.lod()로 다운로드 후 tensorflow로 사용 가능할 수 있도록 로딩됨
# * 로딩된 모델은 바로 원본 이미지로 Object Detection이 가능. 입력 이미지 값으로 numpy array, tensor 모두 가능하며 uint8로 구성 필요.
# * inference 결과는 dictionary 형태로 반환되며, 개별 key값은 Object Detection 모델에 따라 달라질 수 있음. 개별 value는 tensor로 되어 있음.
# * inference 반환된 bbox 좌표는 이미지 사이즈 대비 스케일링 된 0~1 사이 값이며 **ymin, xmin, ymax, xmax 형태로 반환되므로 반드시 주의 필요**

# %%
# https://tfhub.dev/ 에서 ssd 로 해당 pretrained 모델의 URL 가져옴. 
module_handle = "https://tfhub.dev/tensorflow/ssd_mobilenet_v2/2"
detector_model = hub.load(module_handle)
# Out:
# 2022-05-20 15:45:29.648311: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:936] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-20 15:45:29.648611: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-05-20 15:45:29.648652: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-05-20 15:45:29.648681: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-05-20 15:45:29.667697: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-05-20 15:45:29.667754: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-05-20 15:45:29.667810: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-05-20 15:45:29.667821: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-05-20 15:45:29.668434: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import cv2
import numpy as np
import time

# 3차원 numpy array를 4차원으로 변경
img_array_np = cv2.imread('./data/beatles01.jpg')
img_array = img_array_np[np.newaxis, ...]
print(img_array_np.shape, img_array.shape)

start_time = time.time()
# image를 detector_model에 인자로 입력하여 inference 수행. 
result = detector_model(img_array)
print('elapsed time:', time.time()-start_time)
# Out:
# (633, 806, 3) (1, 633, 806, 3)
# elapsed time: 0.014648199081420898

# %%
# 4차원 tensor로 이미지를 입력 
img_tensor = tf.convert_to_tensor(img_array_np, dtype=tf.uint8)[tf.newaxis, ...]
start_time = time.time()
# image를 detector_model에 인자로 입력하여 inference 수행. 
result = detector_model(img_tensor)
print('elapsed time:', time.time()-start_time)
# Out:
# elapsed time: 0.014903545379638672

# %%
# inference 결과 출력. dictionary 형태의 출력 결과. dict내부의 key는 model 별로 서로 다름. 출력하여 key값 확인 필요. 
print(result)
# Out:
# {'detection_boxes': <tf.Tensor: shape=(1, 100, 4), dtype=float32, numpy=
#         [0.31324178, 0.85715324, 0.39917725, 0.89073724],
#         [0.44351608, 0.5783749 , 0.5297672 , 0.6219894 ],
#         [0.35546142, 0.66919553, 0.4534282 , 0.7328212 ],
#         [0.4044894 , 0.43556827, 0.99030757, 0.9386645 ],
#         [0.6472204 , 0.618993  , 0.700866  , 0.6503585 ]]], dtype=float32)>, 'raw_detection_scores': <tf.Tensor: shape=(1, 1917, 91), dtype=float32, numpy=
# array([[[0.00249344, 0.0137023 , 0.00740916, ..., 0.00415546,
#          0.00335598, 0.00661689],
#         [0.00249356, 0.00473121, 0.00341555, ..., 0.00218213,
#          0.00290629, 0.00123379],
#         [0.00249335, 0.00371736, 0.00301272, ..., 0.00119156,
#          0.00268269, 0.00110501],
#         ...,
#         [0.00920269, 0.03282565, 0.01524714, ..., 0.01217234,
#          0.00927728, 0.01237863],
#         [0.00920284, 0.03090179, 0.0117254 , ..., 0.01085666,
#          0.00986129, 0.01220304],
#         [0.00920385, 0.11744446, 0.0219599 , ..., 0.01482099,
#          0.01279017, 0.01489437]]], dtype=float32)>, 'raw_detection_boxes': <tf.Tensor: shape=(1, 1917, 4), dtype=float32, numpy=
# array([[[ 0.00631277,  0.00904143,  0.03609156,  0.03401439],
#         [-0.00856349, -0.07280225,  0.06101339,  0.17188805],
#         [-0.06701753, -0.02872823,  0.15511248,  0.09277534],
#         ...,
#         [ 0.23607212, -0.05441433,  0.8210624 ,  1.050818  ],
#         [-0.04293114,  0.19815397,  1.0614538 ,  0.8055974 ],
#         [ 0.23631245,  0.02928039,  0.9821289 ,  0.9564252 ]]],
#       dtype=float32)>, 'detection_classes': <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[ 1.,  3.,  1.,  3.,  3.,  1.,  3.,  3.,  3.,  3.,  3.,  3.,  1.,
#          1.,  3.,  3.,  3.,  3.,  3.,  1.,  3.,  8.,  1.,  4.,  1.,  3.,
#          3.,  3.,  1.,  1.,  1.,  1.,  3.,  1.,  1.,  1.,  1.,  2.,  1.,
#          1., 41., 15., 15.,  9.,  1.,  3.,  3.,  1.,  1., 15.,  4.,  1.,
#          1., 15.,  1., 28., 37.,  8.,  1.,  3.,  4., 10.,  3.,  8.,  1.,
#          1.,  3.,  1.,  1., 31.,  9.,  3.,  1.,  1.,  8.,  3.,  1.,  3.,
#          1., 31., 15.,  1., 31.,  3.,  1.,  1.,  3.,  1.,  1., 37.,  4.,
#         10., 31., 31.,  3.,  1.,  1.,  8.,  1., 34.]], dtype=float32)>, 'num_detections': <tf.Tensor: shape=(1,), dtype=float32, numpy=array([100.], dtype=float32)>, 'detection_scores': <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[0.8017293 , 0.7356189 , 0.7120169 , 0.69413877, 0.66365266,
#         0.65565014, 0.6452405 , 0.60372716, 0.6026705 , 0.5842154 ,
#         0.56527364, 0.535041  , 0.53426546, 0.526875  , 0.5205358 ,
#         0.50956285, 0.49783003, 0.49455032, 0.49444318, 0.4815372 ,
#         0.46322033, 0.44349003, 0.43932414, 0.43850374, 0.4356334 ,
#         0.42940426, 0.40469143, 0.4024806 , 0.40042177, 0.3880499 ,
#         0.37969688, 0.37923136, 0.35729298, 0.35150278, 0.35130867,
#         0.34515998, 0.34445164, 0.34312052, 0.34093913, 0.34077543,
#         0.33898032, 0.33623463, 0.3346394 , 0.32812503, 0.32567793,
#         0.325413  , 0.32011718, 0.319438  , 0.31624943, 0.31623796,
#         0.31335816, 0.31307602, 0.31300873, 0.30830514, 0.305431  ,
#         0.30098647, 0.29715002, 0.2968765 , 0.29047674, 0.28944695,
#         0.28902638, 0.28901458, 0.28706467, 0.2829278 , 0.28038418,
#         0.27541238, 0.27536172, 0.27475482, 0.27439404, 0.27360848,
#         0.27360648, 0.27351838, 0.2709425 , 0.26251626, 0.26132268,
#         0.25988424, 0.25868118, 0.25767964, 0.25716895, 0.25641966,
#         0.25436682, 0.25432622, 0.25387323, 0.25331113, 0.25205457,
#         0.25127858, 0.2485326 , 0.24652895, 0.24145931, 0.24071851,
#         0.23723474, 0.2369067 , 0.2368573 , 0.23589954, 0.23545507,
#         0.23444656, 0.23416895, 0.2323947 , 0.22919816, 0.22909537]],
#       dtype=float32)>, 'detection_multiclass_scores': <tf.Tensor: shape=(1, 100, 91), dtype=float32, numpy=
# array([[[0.0052546 , 0.8017293 , 0.01305184, ..., 0.02166343,
#          0.01840499, 0.02373999],
#         [0.00419417, 0.22084358, 0.06346256, ..., 0.00721848,
#          0.00830048, 0.00683111],
#         [0.00508118, 0.7120169 , 0.04037097, ..., 0.02588394,
#          0.01263985, 0.01615295],
#         ...,
#         [0.00419176, 0.35130867, 0.09357271, ..., 0.00898594,
#          0.0057171 , 0.00623852],
#         [0.00536987, 0.22919816, 0.02347153, ..., 0.01477227,
#          0.01721635, 0.02555656],
#         [0.00367397, 0.19315845, 0.0380055 , ..., 0.05451539,
#          0.01729244, 0.07981768]]], dtype=float32)>, 'detection_anchor_indices': <tf.Tensor: shape=(1, 100), dtype=float32, numpy=
# array([[1475.,  435., 1453.,  432.,  369., 1465.,  372.,  420.,  366.,
#          470.,  429.,  441.,  477., 1487.,  447.,  444.,  438.,  375.,
#          477.,  501.,  450.,  435.,  617.,  477.,  593.,  423.,  363.,
#          378.,  605.,  578.,  441.,  366.,  453.,  489.,  438.,  462.,
#         1457.,  477.,  363.,  420., 1015., 1575.,  420., 1569.,  465.,
#          489.,  495., 1555., 1472., 1569.,  495., 1543.,  474.,  477.,
#          417.,  593.,  717.,  432.,  423.,  465.,  492.,  309.,  433.,
#          420.,  378.,  447.,  498.,  369.,  372.,  759., 1580.,  417.,
#          444.,  534.,  375.,  474.,  408.,  501.,  453.,  717., 1611.,
#          450.,  651.,  462.,  495.,  498.,  426.,  821., 1520.,  720.,
#          489.,  312.,  591.,  761.,  357.,  390.,  546.,  438., 1796.,
#          717.]], dtype=float32)>}

# %%
print(result.keys())
# detect 결과는 100개를 기본으로 Detect 함(즉 Detect된 오브젝트는 무조건 100개. 그래서 tensor(array)는 100개 단위)
print(result['detection_boxes'].shape, result['detection_classes'].shape, result['num_detections'].shape, result['detection_scores'].shape)
# Out:
# dict_keys(['detection_boxes', 'raw_detection_scores', 'raw_detection_boxes', 'detection_classes', 'num_detections', 'detection_scores', 'detection_multiclass_scores', 'detection_anchor_indices'])
# (1, 100, 4) (1, 100) (1,) (1, 100)

# %%
# detect된 object들은 detection score가 높은 순으로 array값을 순차적으로 채움. 
print('#### detection_classes #####')
print(result['detection_classes'])
print('#### detection_scores #####')
print(result['detection_scores'])
# Out:
# #### detection_classes #####
# tf.Tensor(
# [[ 1.  3.  1.  3.  3.  1.  3.  3.  3.  3.  3.  3.  1.  1.  3.  3.  3.  3.
#    3.  1.  3.  8.  1.  4.  1.  3.  3.  3.  1.  1.  1.  1.  3.  1.  1.  1.
#    1.  2.  1.  1. 41. 15. 15.  9.  1.  3.  3.  1.  1. 15.  4.  1.  1. 15.
#    1. 28. 37.  8.  1.  3.  4. 10.  3.  8.  1.  1.  3.  1.  1. 31.  9.  3.
#    1.  1.  8.  3.  1.  3.  1. 31. 15.  1. 31.  3.  1.  1.  3.  1.  1. 37.
#    4. 10. 31. 31.  3.  1.  1.  8.  1. 34.]], shape=(1, 100), dtype=float32)
# #### detection_scores #####
# tf.Tensor(
# [[0.8017293  0.7356189  0.7120169  0.69413877 0.66365266 0.65565014
#   0.6452405  0.60372716 0.6026705  0.5842154  0.56527364 0.535041
#   0.53426546 0.526875   0.5205358  0.50956285 0.49783003 0.49455032
#   0.49444318 0.4815372  0.46322033 0.44349003 0.43932414 0.43850374
#   0.4356334  0.42940426 0.40469143 0.4024806  0.40042177 0.3880499
#   0.37969688 0.37923136 0.35729298 0.35150278 0.35130867 0.34515998
#   0.34445164 0.34312052 0.34093913 0.34077543 0.33898032 0.33623463
#   0.3346394  0.32812503 0.32567793 0.325413   0.32011718 0.319438
#   0.31624943 0.31623796 0.31335816 0.31307602 0.31300873 0.30830514
#   0.305431   0.30098647 0.29715002 0.2968765  0.29047674 0.28944695
#   0.28902638 0.28901458 0.28706467 0.2829278  0.28038418 0.27541238
#   0.27536172 0.27475482 0.27439404 0.27360848 0.27360648 0.27351838
#   0.2709425  0.26251626 0.26132268 0.25988424 0.25868118 0.25767964
#   0.25716895 0.25641966 0.25436682 0.25432622 0.25387323 0.25331113
#   0.25205457 0.25127858 0.2485326  0.24652895 0.24145931 0.24071851
#   0.23723474 0.2369067  0.2368573  0.23589954 0.23545507 0.23444656
#   0.23416895 0.2323947  0.22919816 0.22909537]], shape=(1, 100), dtype=float32)

# %%
# bounding box 좌표는 ymin, xmin, ymax, xmax 순서로 반환됨. y가 먼저, x가 나중에 나오므로 반드시 주의해야 함. 
# 좌표 값은 원본 이미지의 width, height로 0~1 사이값으로 정규화됨. 
print('#### detection_boxes #####')
print(result['detection_boxes'])
# Out:
# #### detection_boxes #####
# tf.Tensor(
# [[[0.41495627 0.4789079  0.8861094  0.6805986 ]
#   [0.35446185 0.6193308  0.45601124 0.7103389 ]
#   [0.42462417 0.07202515 0.87260556 0.24962679]
#   [0.34840307 0.57042307 0.4265056  0.6450172 ]
#   [0.351907   0.49550378 0.37206447 0.51862085]
#   [0.4327357  0.2820462  0.8654355  0.45395404]
#   [0.34878334 0.54638815 0.37784776 0.57632303]
#   [0.37359872 0.3855908  0.4141502  0.4274903 ]
#   [0.31169334 0.4673808  0.32902566 0.47657576]
#   [0.33250052 0.5396959  0.45469236 0.7354935 ]
#   [0.37359872 0.3855908  0.4141502  0.4274903 ]
#   [0.33029744 0.6353664  0.36666313 0.6794382 ]
#   [0.37630147 0.84103763 0.4158867  0.8823029 ]
#   [0.39232096 0.7469354  0.48478994 0.791436  ]
#   [0.351907   0.49550378 0.37206447 0.51862085]
#   [0.34878334 0.54638815 0.37784776 0.57632303]
#   [0.6674462  0.32936162 0.7699916  0.38531828]
#   [0.6569795  0.02464624 0.99476236 0.45323312]
#   [0.36354062 0.35883003 0.40801236 0.3800807 ]
#   [0.3869046  0.8088866  0.42234337 0.8531973 ]
#   [0.42875403 0.37704226 0.5624237  0.4172525 ]
#   [0.33963862 0.5889446  0.3827575  0.64008945]
#   [0.41505188 0.3598152  0.4881289  0.38766482]
#   [0.37626094 0.17597067 0.4250462  0.20476246]
#   [0.39901894 0.7998833  0.5149196  0.85316366]
#   [0.36999315 0.9572114  0.44099426 0.9959266 ]
#   [0.6472204  0.618993   0.700866   0.6503585 ]
#   [0.631762   0.68247974 0.9847534  0.9789603 ]
#   [0.37458178 0.89691675 0.4252685  0.94217455]
#   [0.5798783  0.4168563  0.6574103  0.44514084]
#   [0.3994648  0.12330359 0.5087905  0.18180507]
#   [0.3942718  0.67208576 0.46410114 0.7225218 ]
#   [0.39232096 0.7469354  0.48478994 0.791436  ]
#   [0.3582933  0.49141628 0.39310336 0.5128277 ]
#   [0.6160068  0.32744297 0.85219127 0.4621711 ]
#   [0.52013475 0.06693733 0.97443765 0.4353857 ]
#   [0.6612368  0.6260819  0.6986447  0.6584218 ]
#   [0.40350166 0.58089674 0.48797104 0.6291064 ]
#   [0.3059402  0.51938194 0.32466012 0.52911896]
#   [0.4775195  0.3726431  0.6517688  0.43290854]
#   [0.5424087  0.26711664 0.8480818  0.44981095]
#   [0.33906978 0.2670775  0.36577523 0.3006997 ]
#   [0.31324178 0.85715324 0.39917725 0.89073724]
#   [0.44351608 0.5783749  0.5297672  0.6219894 ]
#   [0.35546142 0.66919553 0.4534282  0.7328212 ]
#   [0.4044894  0.43556827 0.99030757 0.9386645 ]
#   [0.6472204  0.618993   0.700866   0.6503585 ]]], shape=(1, 100, 4), dtype=float32)

# %% [markdown]
# ### inference 결과를 이미지로 시각화

# %%
# result내의 value들을 모두 numpy로 변환. 
result = {key:value.numpy() for key,value in result.items()}

# %%
result
# Out:
# {'raw_detection_boxes': array([[[ 0.00564996,  0.00971854,  0.03794352,  0.03380422],
#          [-0.00698605, -0.07109027,  0.06325536,  0.17263879],
#          [-0.06500881, -0.0294233 ,  0.1594105 ,  0.09242779],
#          ...,
#          [ 0.2351011 , -0.04338232,  0.8073013 ,  1.039025  ],
#          [-0.02645707,  0.20638531,  1.0468906 ,  0.8009648 ],
#          [ 0.21540597,  0.06078827,  0.96515584,  0.9366525 ]]],
#        dtype=float32),
#  'detection_anchor_indices': array([[1475., 1453.,  435., 1487.,  432., 1465.,  420.,  369.,  372.,
#           470.,  366.,  429.,  617.,  605.,  438., 1015.,  444.,  435.,
#           447.,  578.,  501.,  441.,  423.,  432.,  477.,  375., 1555.,
#          1611.,  366., 1457.,  536.,  495.,  477., 1543.,  441.,  489.,
#           591.,  420.,  420.,  450.,  438.,  717.,  444.,  591.,  432.,
#          1469.,  378.,  447.,  501.,  534.,  363., 1569.,  378.,  462.,
#           759.,  492.,  420.,  369.,  648.,  717.,  372.,  651.,  591.,
#           752.,  489.,  717.,  805.,  465.,  435.,  363.,  453.,  390.,
#           468.,  917.,  657.,  474.,  495.,  498.,  498.,  477.,  426.,
#           560.,  462.,  423.,  375.,  678.,  941.,  453.,  495.,  450.,
#           438.,  809.,  309.,  821., 1791.,  590.,  429.,  417.,  504.,
#           898.]], dtype=float32),
#  'detection_multiclass_scores': array([[[0.00564212, 0.77672786, 0.01326162, ..., 0.02211455,
#           0.01373172, 0.01871523],
#          [0.0052503 , 0.73624194, 0.04408571, ..., 0.02665284,
#           0.01280436, 0.02267236],
#          [0.00427276, 0.24478784, 0.05446187, ..., 0.0052999 ,
#           0.01016974, 0.00749245],
#          ...,
#          [0.00360632, 0.19915086, 0.05670014, ..., 0.00562188,
#           0.00328878, 0.00768921],
#          [0.00330305, 0.2185531 , 0.0784159 , ..., 0.00833842,
#           0.00603142, 0.00698519],
#          [0.0032135 , 0.04114187, 0.01558399, ..., 0.0116325 ,
#           0.00943872, 0.00818154]]], dtype=float32),
#  'detection_boxes': array([[[0.4211133 , 0.47946256, 0.8877347 , 0.6792243 ],
#          [0.41390574, 0.07580293, 0.8731036 , 0.24651638],
#          [0.35886806, 0.6269066 , 0.45858335, 0.7061376 ],
#          [0.4119116 , 0.6960391 , 0.8809651 , 0.8719262 ],
#          [0.37098876, 0.58545655, 0.42766502, 0.63829595],
#          [0.41002512, 0.28152516, 0.8722112 , 0.44728443],
#          [0.3766286 , 0.38439283, 0.4191282 , 0.43586972],
#          [0.35231823, 0.49213603, 0.3721621 , 0.5167179 ],
#          [0.35521933, 0.5434159 , 0.3808175 , 0.5733013 ],
#          [0.3860718 , 0.16840544, 0.54479706, 0.31282276],
#          [0.35911813, 0.45707306, 0.37529442, 0.47431943],
#          [0.35785085, 0.54057443, 0.40907204, 0.5949993 ],
#          [0.4074384 , 0.74868935, 0.8119439 , 0.8627991 ],
#          [0.42933282, 0.5312217 , 0.80980134, 0.6519688 ],
#          [0.36342457, 0.6675841 , 0.45387575, 0.7361211 ],
#          [0.8340404 , 0.7102666 , 1.        , 0.95186555],
#          [0.38433278, 0.8039728 , 0.42848694, 0.8511749 ],
#          [0.35886806, 0.6269066 , 0.45858335, 0.7061376 ],
#          [0.3755534 , 0.84313047, 0.41416326, 0.8815781 ],
#          [0.41382712, 0.08626936, 0.7868442 , 0.20840581],
#          [0.40619832, 0.7966654 , 0.51229554, 0.8571587 ],
#          [0.35680166, 0.7503358 , 0.4548656 , 0.79742754],
#          [0.3622888 , 0.42000768, 0.3950188 , 0.44961408],
#          [0.37098876, 0.58545655, 0.42766502, 0.63829595],
#          0.39974517, 0.3797992 , 0.37764198, 0.36189842, 0.34877145,
#          0.34851682, 0.34455445, 0.33729   , 0.33652526, 0.33375704,
#          0.3298865 , 0.32964027, 0.32367307, 0.3206504 , 0.31935972,
#          0.31819504, 0.31777602, 0.3029278 , 0.30130637, 0.2952349 ,
#          0.2923266 , 0.288455  , 0.284081  , 0.28292483, 0.28061455,
#          0.2804734 , 0.27564478, 0.27051526, 0.26980752, 0.26930732,
#          0.26860446, 0.26231682, 0.26190624, 0.26141557, 0.25997353,
#          0.25686693, 0.25656286, 0.25547183, 0.254957  , 0.25466532,
#          0.2513795 , 0.25095922, 0.2492491 , 0.24888977, 0.24878165,
#          0.24761775, 0.24732235, 0.24645755, 0.24478784, 0.24402338,
#          0.24314609, 0.240735  , 0.23935848, 0.2364842 , 0.23642716,
#          0.23614034, 0.23296133, 0.23288518, 0.232272  , 0.23200771,
#          0.2311328 , 0.231119  , 0.23081365, 0.22900414, 0.22824502,
#          0.22672555, 0.22569886, 0.22549683, 0.22447646, 0.22425702,
#          0.22390854, 0.22388124, 0.22256479, 0.22206879, 0.22187954,
#          0.22008803, 0.21997559, 0.21920988, 0.2185531 , 0.21674648]],
#        dtype=float32),
#  'detection_classes': array([[ 1.,  1.,  3.,  1.,  3.,  1.,  3.,  3.,  3.,  3.,  3.,  3.,  1.,
#           1.,  3., 41.,  3.,  8.,  3.,  1.,  1.,  3.,  3.,  1.,  1.,  3.,
#           1., 15.,  1.,  1.,  1.,  3.,  3.,  1.,  1.,  1., 32.,  8., 15.,
#           3.,  1., 31.,  1., 31.,  8.,  1.,  1.,  1.,  3., 32.,  3., 15.,
#           3.,  1., 31.,  4.,  1.,  1., 31., 34.,  1., 31., 27., 39.,  3.,
#          37., 41.,  1.,  1.,  1.,  1.,  1.,  8., 15., 31.,  3.,  4.,  3.,
#           1., 15.,  3.,  1.,  3.,  1.,  1., 39., 31.,  3.,  1.,  1.,  8.,
#          41., 10.,  1.,  1.,  1.,  1.,  3.,  1., 41.]], dtype=float32)}

# %%
# 1부터 91까지의 COCO Class id 매핑. 
labels_to_names = {1:'person',2:'bicycle',3:'car',4:'motorcycle',5:'airplane',6:'bus',7:'train',8:'truck',9:'boat',10:'traffic light',
                    11:'fire hydrant',12:'street sign',13:'stop sign',14:'parking meter',15:'bench',16:'bird',17:'cat',18:'dog',19:'horse',20:'sheep',
                    21:'cow',22:'elephant',23:'bear',24:'zebra',25:'giraffe',26:'hat',27:'backpack',28:'umbrella',29:'shoe',30:'eye glasses',
                    31:'handbag',32:'tie',33:'suitcase',34:'frisbee',35:'skis',36:'snowboard',37:'sports ball',38:'kite',39:'baseball bat',40:'baseball glove',
                    41:'skateboard',42:'surfboard',43:'tennis racket',44:'bottle',45:'plate',46:'wine glass',47:'cup',48:'fork',49:'knife',50:'spoon',
                    51:'bowl',52:'banana',53:'apple',54:'sandwich',55:'orange',56:'broccoli',57:'carrot',58:'hot dog',59:'pizza',60:'donut',
                    61:'cake',62:'chair',63:'couch',64:'potted plant',65:'bed',66:'mirror',67:'dining table',68:'window',69:'desk',70:'toilet',
                    71:'door',72:'tv',73:'laptop',74:'mouse',75:'remote',76:'keyboard',77:'cell phone',78:'microwave',79:'oven',80:'toaster',
                    81:'sink',82:'refrigerator',83:'blender',84:'book',85:'clock',86:'vase',87:'scissors',88:'teddy bear',89:'hair drier',90:'toothbrush',
                    91:'hair brush'}

# %%
def get_ssd_detector(module_handle="https://tfhub.dev/tensorflow/ssd_mobilenet_v2/2"):
  detector = hub.load(module_handle)
  return detector

detector_model = get_ssd_detector()

# %%
import cv2

img_array = cv2.cvtColor(cv2.imread('./data/beatles01.jpg'), cv2.COLOR_BGR2RGB)

# scaling된 이미지 기반으로 bounding box 위치가 예측 되므로 이를 다시 원복하기 위해 원본 이미지 shape정보 필요
height = img_array.shape[0]
width = img_array.shape[1]
# cv2의 rectangle()은 인자로 들어온 이미지 배열에 직접 사각형을 업데이트 하므로 그림 표현을 위한 별도의 이미지 배열 생성. 
draw_img = img_array.copy()

# bounding box의 테두리와 caption 글자색 지정
green_color=(0, 255, 0)
red_color=(0, 0, 255)

# cv2로 만들어진 numpy image array를 tensor로 변환
img_tensor = tf.convert_to_tensor(img_array, dtype=tf.uint8)[tf.newaxis, ...]
#img_tensor = tf.convert_to_tensor(img_array, dtype=tf.float32)[tf.newaxis, ...]

# ssd+mobilenet v2 모델을 다운로드 한 뒤 inference 수행. 
result = detector_model(img_tensor)

# result 내부의 value를 numpy 로 변환. 
result = {key:value.numpy() for key,value in result.items()}

SCORE_THRESHOLD = 0.5
OBJECT_DEFAULT_COUNT = 100

# detected 된 object들을 iteration 하면서 정보 추출. detect된 object의 갯수는 100개
for i in range(min(result['detection_scores'][0].shape[0], OBJECT_DEFAULT_COUNT)):
  # detection score를 iteration시 마다 높은 순으로 추출하고 SCORE_THRESHOLD보다 낮으면 loop 중단. 
  score = result['detection_scores'][0, i]
  if score < SCORE_THRESHOLD:
    break
  # detected된 object들은 scale된 기준으로 예측되었으므로 다시 원본 이미지 비율로 계산
  box = result['detection_boxes'][0, i]

  ''' **** 주의 ******
   box는 ymin, xmin, ymax, xmax 순서로 되어 있음. '''
  left = box[1] * width
  top = box[0] * height
  right = box[3] * width
  bottom = box[2] * height

  # class id 추출하고 class 명으로 매핑
  class_id = result['detection_classes'][0, i]
  caption = "{}: {:.4f}".format(labels_to_names[class_id], score)
  print(caption)
  #cv2.rectangle()은 인자로 들어온 draw_img에 사각형을 그림. 위치 인자는 반드시 정수형.
  cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color=green_color, thickness=2)
  cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.4, red_color, 1)

plt.figure(figsize=(12, 12))
plt.imshow(draw_img)
# Out:
# person: 0.7767
# person: 0.7362
# car: 0.7209
# person: 0.7084
# car: 0.6868
# person: 0.6846
# car: 0.6652
# car: 0.6145
# car: 0.5854
# car: 0.5724
# car: 0.5606
# car: 0.5341
# person: 0.5228

# %%
import time

def get_detected_img(model, img_array, score_threshold, object_show_count=100, is_print=True):   
  # scaling된 이미지 기반으로 bounding box 위치가 예측 되므로 이를 다시 원복하기 위해 원본 이미지 shape정보 필요
  height = img_array.shape[0]
  width = img_array.shape[1]
  # cv2의 rectangle()은 인자로 들어온 이미지 배열에 직접 사각형을 업데이트 하므로 그림 표현을 위한 별도의 이미지 배열 생성. 
  draw_img = img_array.copy()

  # bounding box의 테두리와 caption 글자색 지정
  green_color=(0, 255, 0)
  red_color=(0, 0, 255)

  # cv2로 만들어진 numpy image array를 tensor로 변환
  img_tensor = tf.convert_to_tensor(img_array, dtype=tf.uint8)[tf.newaxis, ...]
  #img_tensor = tf.convert_to_tensor(img_array, dtype=tf.float32)[tf.newaxis, ...]

  # ssd+mobilenet v2 모델을 다운로드 한 뒤 inference 수행. 
  start_time = time.time()
  result = model(img_tensor)
  # result 내부의 value를 numpy 로 변환. 
  result = {key:value.numpy() for key,value in result.items()}

  # detected 된 object들을 iteration 하면서 정보 추출. detect된 object의 갯수는 100개
  for i in range(min(result['detection_scores'][0].shape[0], object_show_count)):
    # detection score를 iteration시 마다 높은 순으로 추출하고 SCORE_THRESHOLD보다 낮으면 loop 중단. 
    score = result['detection_scores'][0, i]
    if score < score_threshold:
      break
    # detected된 object들은 scale된 기준으로 예측되었으므로 다시 원본 이미지 비율로 계산
    box = result['detection_boxes'][0, i]

    ''' **** 주의 ******
    box는 ymin, xmin, ymax, xmax 순서로 되어 있음. '''
    left = box[1] * width
    top = box[0] * height
    right = box[3] * width
    bottom = box[2] * height

    # class id 추출하고 class 명으로 매핑
    class_id = result['detection_classes'][0, i]
    caption = "{}: {:.4f}".format(labels_to_names[class_id], score)
    print(caption)
    #cv2.rectangle()은 인자로 들어온 draw_img에 사각형을 그림. 위치 인자는 반드시 정수형.
    cv2.rectangle(draw_img, (int(left), int(top)), (int(right), int(bottom)), color=green_color, thickness=2)
    cv2.putText(draw_img, caption, (int(left), int(top - 5)), cv2.FONT_HERSHEY_SIMPLEX, 0.4, red_color, 1)

  if is_print:
    print('Detection 수행시간:',round(time.time() - start_time, 2),"초")

  return draw_img

# %%
#detector_model = get_ssd_detector()

img_array = cv2.cvtColor(cv2.imread('./data/beatles01.jpg'), cv2.COLOR_BGR2RGB)
draw_img = get_detected_img(detector_model, img_array, score_threshold=0.5, object_show_count=100, is_print=True)

plt.figure(figsize=(12, 12))
plt.imshow(draw_img)
# Out:
# person: 0.7767
# person: 0.7362
# car: 0.7209
# person: 0.7084
# car: 0.6868
# person: 0.6846
# car: 0.6652
# car: 0.6145
# car: 0.5854
# car: 0.5724
# car: 0.5606
# car: 0.5341
# person: 0.5228
# Detection 수행시간: 0.02 초

# %%
# !wget -O ./data/baseball01.jpg https://raw.githubusercontent.com/chulminkw/DLCV/master/data/image/baseball01.jpg

# %%
img_array = cv2.cvtColor(cv2.imread('./data/baseball01.jpg'), cv2.COLOR_BGR2RGB)
draw_img = get_detected_img(detector_model, img_array, score_threshold=0.5, object_show_count=100, is_print=True)

plt.figure(figsize=(12, 12))
plt.imshow(draw_img)
# Out:
# person: 0.8886
# person: 0.8754
# person: 0.8638
# baseball bat: 0.5842
# baseball glove: 0.5645
# baseball glove: 0.5182
# baseball bat: 0.5007
# Detection 수행시간: 0.02 초

# %% [markdown]
# ### Video Inference 수행

# %%
# !wget -O ./data/Jonh_Wick_small.mp4 https://github.com/chulminkw/DLCV/blob/master/data/video/John_Wick_small.mp4?raw=true

# %%
def do_detected_video(model, input_path, output_path, score_threshold, is_print):
    
    cap = cv2.VideoCapture(input_path)

    codec = cv2.VideoWriter_fourcc(*'XVID')

    vid_size = (round(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),round(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    vid_fps = cap.get(cv2.CAP_PROP_FPS)

    vid_writer = cv2.VideoWriter(output_path, codec, vid_fps, vid_size) 

    frame_cnt = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print('총 Frame 갯수:', frame_cnt)

    green_color=(0, 255, 0)
    red_color=(0, 0, 255)
    while True:
        hasFrame, img_frame = cap.read()
        if not hasFrame:
            print('더 이상 처리할 frame이 없습니다.')
            break
        
        img_frame = get_detected_img(model, img_frame, score_threshold=score_threshold, object_show_count=100, is_print=is_print)
        
        vid_writer.write(img_frame)
    # end of while loop

    vid_writer.release()
    cap.release()

# %%
do_detected_video(detector_model, './data/Jonh_Wick_small.mp4', './data/John_Wick_small_02.mp4', 0.5, True)
# Out:
# OpenCV: FFMPEG: tag 0x44495658/'XVID' is not supported with codec id 12 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# 총 Frame 갯수: 58
# car: 0.6785
# car: 0.5698
# car: 0.5395
# Detection 수행시간: 0.02 초
# car: 0.6946
# car: 0.5763
# car: 0.5395
# Detection 수행시간: 0.01 초
# motorcycle: 0.6226
# person: 0.5840
# car: 0.5559
# Detection 수행시간: 0.02 초
# car: 0.5359
# person: 0.5348
# car: 0.5228
# Detection 수행시간: 0.02 초
# car: 0.6281
# car: 0.6254
# motorcycle: 0.6097
# person: 0.5842
# Detection 수행시간: 0.01 초
# car: 0.6241
# person: 0.6053
# car: 0.5280
# Detection 수행시간: 0.01 초
# car: 0.6307
# person: 0.5982
# car: 0.5157
# Detection 수행시간: 0.02 초
# car: 0.6952
# person: 0.6058
# motorcycle: 0.5257
# motorcycle: 0.5150
# Detection 수행시간: 0.02 초
# person: 0.6923
# car: 0.6280
# motorcycle: 0.5511
# car: 0.5127
# Detection 수행시간: 0.01 초
# person: 0.6850
# car: 0.6466
# car: 0.5946
# motorcycle: 0.5325
# Detection 수행시간: 0.02 초
# car: 0.6627
# car: 0.6265
# person: 0.5025
# Detection 수행시간: 0.02 초
# car: 0.6668
# car: 0.6445
# person: 0.5397
# motorcycle: 0.5068
# Detection 수행시간: 0.02 초
# person: 0.5929
# car: 0.5350
# Detection 수행시간: 0.02 초
# person: 0.6150
# car: 0.5573
# car: 0.5510
# person: 0.5106
# person: 0.5007
# Detection 수행시간: 0.02 초
# person: 0.6123
# car: 0.5505
# car: 0.5393
# person: 0.5189
# person: 0.5102
# Detection 수행시간: 0.01 초
# person: 0.6398
# Detection 수행시간: 0.01 초
# Detection 수행시간: 0.02 초
# person: 0.5472
# Detection 수행시간: 0.01 초
# person: 0.6628
# bottle: 0.5190
# car: 0.5034
# Detection 수행시간: 0.01 초
# person: 0.6688
# car: 0.5202
# bottle: 0.5103
# Detection 수행시간: 0.01 초
# person: 0.6341
# car: 0.5959
# bus: 0.5432
# car: 0.5081
# Detection 수행시간: 0.02 초
# person: 0.6386
# car: 0.5442
# car: 0.5322
# car: 0.5275
# car: 0.5155
# car: 0.5116
# Detection 수행시간: 0.02 초
# person: 0.5948
# car: 0.5570
# car: 0.5100
# Detection 수행시간: 0.02 초
# person: 0.5818
# person: 0.5276
# Detection 수행시간: 0.01 초
# person: 0.5901
# person: 0.5641
# bus: 0.5003
# Detection 수행시간: 0.01 초
# person: 0.6057
# person: 0.5158
# Detection 수행시간: 0.01 초
# person: 0.6995
# Detection 수행시간: 0.01 초
# person: 0.6707
# person: 0.5195
# Detection 수행시간: 0.01 초
# person: 0.5998
# horse: 0.5421
# horse: 0.5294
# person: 0.5207
# Detection 수행시간: 0.02 초
# person: 0.6080
# person: 0.5229
# horse: 0.5219
# horse: 0.5119
# Detection 수행시간: 0.02 초
# person: 0.6762
# person: 0.6535
# person: 0.5585
# horse: 0.5461
# bicycle: 0.5038
# Detection 수행시간: 0.02 초
# person: 0.6766
# car: 0.5945
# person: 0.5514
# car: 0.5370
# bicycle: 0.5253
# Detection 수행시간: 0.01 초
# person: 0.6245
# car: 0.5651
# traffic light: 0.5581
# person: 0.5424
# person: 0.5356
# person: 0.5356
# person: 0.5018
# Detection 수행시간: 0.02 초
# person: 0.6915
# person: 0.5930
# person: 0.5812
# car: 0.5774
# Detection 수행시간: 0.01 초
# person: 0.6926
# person: 0.6061
# person: 0.5925
# car: 0.5830
# Detection 수행시간: 0.01 초
# person: 0.6351
# car: 0.6197
# person: 0.6068
# traffic light: 0.5626
# person: 0.5192
# person: 0.5168
# Detection 수행시간: 0.01 초
# car: 0.6546
# traffic light: 0.6085
# horse: 0.6054
# person: 0.5948
# person: 0.5667
# person: 0.5603
# person: 0.5466
# Detection 수행시간: 0.02 초
# person: 0.6837
# car: 0.6702
# traffic light: 0.6097
# person: 0.5951
# horse: 0.5890
# person: 0.5676
# person: 0.5269
# car: 0.5085
# Detection 수행시간: 0.01 초
# car: 0.7027
# person: 0.6700
# traffic light: 0.6458
# horse: 0.5656
# car: 0.5456
# person: 0.5337
# person: 0.5322
# person: 0.5264
# Detection 수행시간: 0.01 초
# car: 0.6950
# person: 0.6624
# traffic light: 0.6526
# horse: 0.5467
# car: 0.5409
# person: 0.5269
# person: 0.5240
# person: 0.5222
# Detection 수행시간: 0.01 초
# car: 0.7232
# person: 0.5619
# traffic light: 0.5199
# car: 0.5083
# person: 0.5082
# Detection 수행시간: 0.01 초
# car: 0.7457
# person: 0.5528
# person: 0.5369
# person: 0.5282
# Detection 수행시간: 0.01 초
# car: 0.6937
# person: 0.5589
# vase: 0.5419
# person: 0.5218
# person: 0.5080
# Detection 수행시간: 0.01 초
# car: 0.5724
# bus: 0.5472
# motorcycle: 0.5458
# person: 0.5220
# vase: 0.5039
# Detection 수행시간: 0.01 초
# car: 0.5550
# motorcycle: 0.5542
# bus: 0.5274
# person: 0.5271
# vase: 0.5032
# person: 0.5020
# Detection 수행시간: 0.02 초
# car: 0.7071
# vase: 0.5979
# person: 0.5028
# Detection 수행시간: 0.01 초
# car: 0.7098
# person: 0.5332
# vase: 0.5317
# Detection 수행시간: 0.02 초
# car: 0.6929
# bus: 0.5771
# vase: 0.5359
# Detection 수행시간: 0.01 초
# car: 0.6418
# person: 0.5776
# car: 0.5208
# Detection 수행시간: 0.01 초
# car: 0.6493
# person: 0.5804
# car: 0.5263
# Detection 수행시간: 0.02 초
# car: 0.6665
# person: 0.6507
# Detection 수행시간: 0.01 초
# car: 0.7281
# person: 0.6240
# person: 0.5704
# Detection 수행시간: 0.01 초
# car: 0.7511
# person: 0.6729
# person: 0.5862
# person: 0.5344
# Detection 수행시간: 0.02 초
# car: 0.7232
# person: 0.6110
# person: 0.5641
# car: 0.5231
# person: 0.5049
# horse: 0.5026
# Detection 수행시간: 0.02 초
# car: 0.7181
# person: 0.6237
# person: 0.5375
# car: 0.5233
# person: 0.5055
# horse: 0.5021
# Detection 수행시간: 0.02 초
# car: 0.7298
# car: 0.6428
# person: 0.6032
# person: 0.5754
# horse: 0.5657
# horse: 0.5523
# person: 0.5404
# car: 0.5139
# Detection 수행시간: 0.02 초
# car: 0.6638
# car: 0.6588
# horse: 0.6207
# person: 0.6062
# horse: 0.5429
# car: 0.5243
# person: 0.5212
# Detection 수행시간: 0.02 초
# car: 0.6678
# horse: 0.6562
# car: 0.6168
# person: 0.6001
# car: 0.5463
# person: 0.5198
# Detection 수행시간: 0.02 초
# 더 이상 처리할 frame이 없습니다.
